# %%
import mytools
import pandas as pd

# %%
数据表 = mytools.读取SPSS数据文件(R'国家认同数据清理后.sav')

# %%
# 创建年级、政治面貌和会以中国人自豪吗的交互表
cross_tab = pd.crosstab(index=[数据表['政治面貌'], 数据表['会以中国人自豪吗']], 
                        columns=数据表['年级'], 
                        margins=True, normalize=True)  # All 行和列的总和

cross_tab
# Out:
# 年级                   预科        大一        大二        大三        大四       All
# 政治面貌 会以中国人自豪吗
# 团员   不会        0.001284  0.003851  0.005135  0.002567  0.002567  0.015404
#      不太会       0.003851  0.017972  0.015404  0.003851  0.003851  0.044929
#      无所谓       0.005135  0.029525  0.038511  0.017972  0.010270  0.101412
#      有些        0.001284  0.075738  0.078306  0.032092  0.015404  0.202824
#      会         0.003851  0.164313  0.107831  0.055199  0.041078  0.372272
# 党员   不会        0.000000  0.000000  0.003851  0.002567  0.000000  0.006418
#      不太会       0.000000  0.001284  0.000000  0.007702  0.003851  0.012837
#      无所谓       0.000000  0.001284  0.012837  0.005135  0.001284  0.020539
#      有些        0.000000  0.002567  0.005135  0.017972  0.010270  0.035944
#      会         0.000000  0.010270  0.012837  0.023107  0.010270  0.056483
# 群众   不太会       0.000000  0.001284  0.000000  0.002567  0.000000  0.003851
# ...

# %%
from scipy import stats
# 假设我们关注的是第二年级的学生（假设年级用数字“大二”表示）
specific_grade = "大三"

# 筛选出特定年级的数据
df_specific_grade = 数据表[数据表['年级'] == specific_grade]

# 创建政治面貌和会以中国人自豪吗的交互表
cross_tab_specific_grade = pd.crosstab(df_specific_grade['政治面貌'], df_specific_grade['会以中国人自豪吗'])

# 进行卡方检验
chi2_grade, p_grade, dof_grade, expected_grade = stats.chi2_contingency(cross_tab_specific_grade)

print(chi2_grade,p_grade)
cross_tab_specific_grade
# Out:
# 16.610955615265958 0.16482706405625666
# 会以中国人自豪吗  不会  不太会  无所谓  有些   会
# 政治面貌
# 团员         2    3   14  25  43
# 党员         2    6    4  14  18
# 群众         0    2    8   7   5
# 其他         0    0    2   3   3

# %%
mytools.两个无序类别变量的统计分析(df_specific_grade,'政治面貌','会以中国人自豪吗')
# Out:
# tau_y系数: 0.0264 极弱相关或无相关
# ----  -  -  --  --  --
# 团员  2  3  14  25  43
# 党员  2  6   4  14  18
# 群众  0  2   8   7   5
# 其他  0  0   2   3   3
# ----  -  -  --  --  --
# 卡方值： 16.61, p值： 0.1648,自由度:12。
# 接受虚无假设
